# %%
#Se valoran todos los datos posibles a analizar en las tablas
import pandas as pd
df = pd.read_csv(r'C:\Users\irene\Documents\TFM_Master_Big_Data_-_Data_Science\data\raw\raw_ache_alzheimer.csv')
print(df.columns.tolist())
# Out:
# ['action_type', 'activity_comment', 'activity_id', 'activity_properties', 'assay_chembl_id', 'assay_description', 'assay_type', 'assay_variant_accession', 'assay_variant_mutation', 'bao_endpoint', 'bao_format', 'bao_label', 'canonical_smiles', 'data_validity_comment', 'data_validity_description', 'document_chembl_id', 'document_journal', 'document_year', 'ligand_efficiency', 'molecule_chembl_id', 'molecule_pref_name', 'parent_molecule_chembl_id', 'pchembl_value', 'potential_duplicate', 'qudt_units', 'record_id', 'relation', 'src_id', 'standard_flag', 'standard_relation', 'standard_text_value', 'standard_type', 'standard_units', 'standard_upper_value', 'standard_value', 'target_chembl_id', 'target_organism', 'target_pref_name', 'target_tax_id', 'text_value', 'toid', 'type', 'units', 'uo_units', 'upper_value', 'value']

# %%
df
# Out:
#                                            action_type activity_comment  \
# 0                                                  NaN              NaN
# 1                                                  NaN              NaN
# 2                                                  NaN              NaN
# 3                                                  NaN              NaN
# 4                                                  NaN              NaN
# ..                                                 ...              ...
# 425  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
# 426  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
# 427  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
# 428  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
# 429  {'action_type': 'INHIBITOR', 'description': 'N...              NaN
#
#      activity_id                                activity_properties  \
# ...

# %% [markdown]
# 1. 🧪 Identificación y Estructura Química\
# Variable,Definición Técnica\
# molecule_chembl_id,Identificador único de la molécula en la base de datos ChEMBL.\
# molecule_pref_name,Nombre común o comercial preferido de la molécula.\
# parent_molecule_chembl_id,ID de la molécula progenitora (agrupa sales o formas libres).\
# canonical_smiles,Representación en texto de la estructura química (formato SMILES).\
# ligand_efficiency,Métricas que relacionan la afinidad de unión con el tamaño molecular.\
#
# 2. ⚡ Métricas de Actividad Biológica (Potencia)\
# Variable,Definición Técnica\
# activity_id,Identificador único del registro de actividad biológica.\
# standard_type,"Tipo de medida estandarizada (ej. IC50, Ki, EC50)."\
# standard_value,Valor numérico de la potencia en unidades estándar.\
# standard_units,Unidades de medida estandarizadas (generalmente nM o nanomolar).\
# pchembl_value,Escala logarítmica de la potencia (−log(IC50​)).\
# standard_relation,"Operador de relación para el valor estándar (=, <, >, etc.)."\
# relation,Operador de relación original reportado.\
# value / units,Valor y unidades originales tal cual se reportaron en la fuente.\
# action_type,"Mecanismo de acción (Inhibidor, Agonista, Antagonista)."\
# activity_comment,Notas u observaciones cualitativas del resultado.\
# 3. 🔬 Metodología del Ensayo (Assay)\
# Variable,Definición Técnica\
# assay_chembl_id,Identificador único del experimento (ensayo).\
# assay_description,Descripción del protocolo experimental seguido en el laboratorio.\
# assay_type,"Categoría (B: Binding, F: Functional, A: ADME, etc.)."\
# bao_label,Etiqueta de clasificación según la BioAssay Ontology.\
# bao_format,Formato físico del ensayo (ej. bioquímico o basado en células).\
# qudt_units / uo_units,Unidades codificadas bajo estándares ontológicos internacionales.\
# assay_variant_mutation,Indica si se usó una proteína con mutaciones específicas.\
# 4. 🎯 Diana Terapéutica (Target)\
# Variable,Definición Técnica\
# target_chembl_id,Identificador único de la proteína diana.\
# target_pref_name,Nombre completo de la proteína (Acetylcholinesterase).\
# target_organism,Organismo de origen de la diana (ej. Homo sapiens).\
# target_tax_id,ID taxonómico de la especie en el NCBI.\
# 5. 📚 Documentación y Origen\
# Variable,Definición Técnica\
# document_chembl_id,ID del artículo científico o patente de origen.\
# document_journal,Revista científica donde se publicó el estudio.\
# document_year,Año de publicación (útil para series temporales).\
# src_id,Identificador de la base de datos fuente.\
# 6. 🛠️ Validación y Calidad del Dato\
# Variable,Definición Técnica\
# data_validity_comment,Comentarios sobre la integridad o posibles errores del registro.\
# potential_duplicate,Flag que indica si el registro se sospecha duplicado (1 = Sí).\
# standard_flag,Indica si el registro ha pasado el proceso de normalización de ChEMBL.\
# upper_value,Límite superior en caso de que la actividad sea un rango de valores.\
